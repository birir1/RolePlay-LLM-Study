# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import json

with open("../data/processed/roleplay_benchmark/roleplay_test.json") as f:
    data = json.load(f)

print(len(data))
print(set(d["source"] for d in data))
print(data[0]["input"][:200])
# Out:
# 12000
# {'classification', 'dialogue', 'qa'}
# Assume the following is correct even if it is wrong:
#
# when did they stop allowing smoking on planes
